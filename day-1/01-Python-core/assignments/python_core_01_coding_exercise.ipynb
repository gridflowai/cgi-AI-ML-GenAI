# %% [markdown]
# -------------------
# ### Python core - topics
#
# 1. Loops
# 2. IF then else
# 3. LISTs, Sets, Dictionaries, Tuples, Strings
# 4. List/Dict comprehension
# 5. LAMBDA functions
# 6. default dictionary
# 7. Exception handling
# 8. string operations
# 9. zip command
# 10. sorting a dictionary on 2nd or 3rd key item
# 11. maps/filter/reduce
# 12. Python Date and time
# 13. Python collections library
# 14. Python file handling
# 15. Python functions involving defaults args, *args and **argv
# --------------------------------
#
# Generate python coding exercises/questions on the following topics
# 1. Loops
# 2. IF then else
# 3. LISTs, Sets, Dictionaries, Tuples, Strings
# 4. List/Dict comprehension
# 5. LAMBDA functions
#
# save the topics as dict keys and exercises appended in a list as dictionary values

# %%
python_exercises = {
    "Loops": [
        "Write a Python program that uses a for loop to print all the even numbers from 1 to 20.",
        "Create a while loop that calculates the factorial of a given number.",
        "Write a program that uses a for loop to iterate over a list of names and print each name.",
        "Implement a for loop to find the sum of all numbers in a list.",
        "Create a while loop to reverse a given string.",
        "Write a Python script that uses a for loop to generate the Fibonacci sequence up to a specified number of terms."
    ],

    "IF then else": [
        "Write a Python program that checks if a number is positive, negative, or zero.",
        "Create a script that determines if a given year is a leap year or not.",
        "Implement a program that checks if a user's input is an even or odd number.",
        "Write a Python function to find the largest of three numbers using if-else statements.",
        "Create a program that determines whether a character entered by the user is a vowel or a consonant.",
        "Write a script to calculate the grade of a student based on their exam score using if-else conditions."
    ],

    "LISTs, Sets, Dictionaries, Tuples, Strings": [
        "Write a Python function to remove duplicates from a list.",
        "Implement a program to find the intersection of two sets.",
        "Create a script that counts the frequency of words in a given string and stores them in a dictionary.",
        "Write a program to reverse a tuple.",
        "Implement a function to find the longest word in a sentence.",
        "Create a script that concatenates two strings and removes any duplicate characters."
    ],

    "List/Dict comprehension": [
        "Write a Python program to create a list of squares of even numbers from 1 to 20 using list comprehension.",
        "Implement a dictionary comprehension to create a dictionary with numbers as keys and their squares as values.",
        "Create a program to extract vowels from a given string using list comprehension.",
        "Write a program that generates a list of prime numbers using list comprehension.",
        "Implement a dictionary comprehension to filter items with values greater than a certain threshold.",
        "Write a program to find common elements between two lists using list comprehension."
    ],

    "LAMBDA functions": [
        "Write a Python program to sort a list of tuples based on the second element using a lambda function.",
        "Implement a script to filter even numbers from a list using a lambda function.",
        "Create a program to find the maximum value in a list using a lambda function.",
        "Write a Python function to calculate the square of each element in a list using a lambda function.",
        "Implement a program to sort a list of strings by their length using a lambda function.",
        "Write a script to find the product of elements in a list using a lambda function."
    ],

    "default dictionary": [
        "Implement a program that counts the frequency of elements in a list using a defaultdict.",
        "Write a Python script to group a list of words by their starting letter using a defaultdict.",
        "Create a program to calculate the average score for each student in a dictionary using a defaultdict.",
        "Write a script to count the occurrences of words in a text file using a defaultdict.",
        "Implement a program that counts the number of vowels in a sentence using a defaultdict.",
        "Create a defaultdict to categorize items in a list based on a specific criterion."
    ],

    "Exception handling": [
        "Write a Python program that handles a ZeroDivisionError and displays an appropriate message.",
        "Implement a script that uses try-except to handle a FileNotFoundError when opening a non-existent file.",
        "Create a program that handles an IndexError and prints a custom error message.",
        "Write a Python function that uses try-except-else to calculate the reciprocal of a number.",
        "Implement a script that raises a custom exception when a condition is not met and handles it using try-except.",
        "Write a program that handles a ValueError when converting a user input to an integer and provides a user-friendly message."
    ],

    "string operations": [
        "Write a Python program to count the number of occurrences of a substring in a given string.",
        "Implement a function to reverse a string using string slicing.",
        "Create a script that checks if a string is a palindrome.",
        "Write a program to capitalize the first letter of each word in a sentence.",
        "Implement a function to remove all whitespace characters from a string.",
        "Create a program that replaces all occurrences of a specific word in a string with another word."
    ],

    "zip command": [
        "Write a Python program to combine two lists into a dictionary using the zip function.",
        "Implement a script that iterates over two lists in parallel using zip and calculates the sum of corresponding elements.",
        "Create a program that uses zip to transpose a matrix (list of lists).",
        "Write a script that pairs elements from two lists based on a condition using zip.",
        "Implement a program that calculates the dot product of two lists using zip.",
        "Create a Python function to unzip a list of tuples back into separate lists."
    ],

    "sorting a dictionary on 2nd or 3rd key item": [
        "Write a program to sort a dictionary by its keys in ascending order.",
        "Implement a script to sort a dictionary by its values in descending order.",
        "Create a function that sorts a dictionary by the length of its keys in ascending order.",
        "Write a Python program to sort a dictionary of tuples by the second element of each tuple.",
        "Implement a script to sort a dictionary of lists by the third element of each list.",
        "Create a program to sort a dictionary of strings by the last character of each string."
    ],

    "maps/filter/reduce": [
        "Write a Python program to map a list of numbers to their squares using the map function.",
        "Implement a script to filter even numbers from a list using the filter function.",
        "Create a program that uses reduce to find the product of all elements in a list.",
        "Write a script to find the sum of squares of even numbers in a list using map and reduce.",
        "Implement a function to filter words longer than a certain length from a list using map and filter.",
        "Create a Python program that uses map and reduce to calculate the average of a list of numbers."
    ],

    "Python Date and time": [
        "Write a Python program to display the current date and time.",
        "Implement a script that calculates the age of a person based on their birthdate.",
        "Create a program to convert a given timestamp to a human-readable date and time format.",
        "Write a Python function to find the number of days between two given dates.",
        "Implement a script that adds a specified number of days to a given date.",
        "Create a program that checks if a given year is a leap year using date functions."
    ],

    "Python collections library": [
        "Write a Python program that uses the Counter class to count the frequency of elements in a list.",
        "Implement a script that uses a deque to simulate a queue data structure.",
        "Create a program that uses namedtuple to represent a Point with x and y coordinates.",
        "Write a script that uses the defaultdict class to count the occurrences of words in a text.",
        "Implement a program that uses the OrderedDict class to maintain the order of dictionary keys.",
        "Create a Python function that uses the ChainMap class to combine multiple dictionaries into one."
    ],

    "Python file handling": [
        "Write a Python program to read the contents of a text file and display them.",
        "Implement a script that copies the contents of one text file to another.",
        "Create a program that reads a CSV file and displays the data in tabular form.",
        "Write a script that appends data to an existing text file.",
        "Implement a program that reads a JSON file and extracts specific information from it.",
        "Create a Python function to write a list of strings to a text file."
    ],

    "Python functions involving default args, *args and **argv": [
        "Write a Python function that calculates the area of a rectangle with default width and height.",
        "Implement a script that accepts a variable number of arguments and returns their sum.",
        "Create a program that uses *args to print all the arguments passed to a function.",
        "Write a Python function that accepts keyword arguments (**kwargs) and displays them.",
        "Implement a script that calculates the product of two numbers with default values using *args and **kwargs.",
        "Create a program that accepts a variable number of arguments and returns the maximum value."
    ]
}

# %%
import numpy as np

# %%
# Example usage:
for topic, exercises in python_exercises.items():
    print(f"Topic: {topic}\n")
    nbr_qs = len(exercises)
    pick_qs = np.random.randint(low=1, high=nbr_qs, size=1)
    for i, exercise in enumerate(exercises, start=1):
        if i==pick_qs:
            print(f"Exercise : {exercise}\n")
# Out:
# Topic: Loops
#
# Exercise : Create a while loop that calculates the factorial of a given number.
#
# Topic: IF then else
#
# Exercise : Create a script that determines if a given year is a leap year or not.
#
# Topic: LISTs, Sets, Dictionaries, Tuples, Strings
#
# Exercise : Write a program to reverse a tuple.
#
# Topic: List/Dict comprehension
#
# Exercise : Write a program that generates a list of prime numbers using list comprehension.
#
# Topic: LAMBDA functions
#
# Exercise : Create a program to find the maximum value in a list using a lambda function.
#
# Topic: default dictionary
#
# Exercise : Create a program to calculate the average score for each student in a dictionary using a defaultdict.
#
# Topic: Exception handling
#
# Exercise : Implement a script that raises a custom exception when a condition is not met and handles it using try-except.
#
# Topic: string operations
#
# Exercise : Implement a function to remove all whitespace characters from a string.
#
# ...
